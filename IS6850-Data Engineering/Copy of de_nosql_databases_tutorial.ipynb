# %% [markdown]
# This tutorial will introduce you to  MongoDB a document database. MongoDB deals in data that is effictively a dictionary in Python or JSON data if it's a file. This document-oriented database is very different from the relational database designs we've seen thus far. We'll learn how to populate the database with data, how to query the database for documents we'd like to find, how to extract data for data engineering purposes.

# %%
# !pip install faker
# !pip install pymongo
# Out:
# Collecting faker
#   Downloading Faker-30.6.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from faker) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Downloading Faker-30.6.0-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 18.0 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-30.6.0
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 22.6 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 10.7 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %%
from faker import Faker
from pymongo import MongoClient
import random
import datetime
import re

# %% [markdown]
# # install MongoDB

# %%
# !apt-get install gnupg curl
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# curl is already the newest version (7.81.0-1ubuntu1.18).
# gnupg is already the newest version (2.2.27-3ubuntu2.1).
# gnupg set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# !curl -fsSL https://pgp.mongodb.com/server-7.0.asc | \
   sudo gpg -o /usr/share/keyrings/mongodb-server-7.0.gpg \
   --dearmor

# %%
# !echo "deb [ arch=amd64,arm64 signed-by=/usr/share/keyrings/mongodb-server-7.0.gpg ] https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0 multiverse" | sudo tee /etc/apt/sources.list.d/mongodb-org-7.0.list
# Out:
# deb [ arch=amd64,arm64 signed-by=/usr/share/keyrings/mongodb-server-7.0.gpg ] https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0 multiverse

# %%
# !apt-get update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Ign:3 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0 InRelease
# Get:4 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0 Release [2,090 B]
# Ign:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Get:8 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0 Release.gpg [866 B]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,031 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,396 kB]
# Get:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:13 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 Packages [53.6 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,372 kB]
# Hit:15 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:16 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse arm64 Packages [52.2 kB]
# Hit:17 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:18 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [33.9 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,200 kB]
# Get:20 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,598 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,162 kB]
# Hit:22 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,648 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,278 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,451 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [33.7 kB]
# Fetched 26.7 MB in 3s (7,657 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !apt-get install -y mongodb-org
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   mongodb-database-tools mongodb-mongosh mongodb-org-database mongodb-org-database-tools-extra
#   mongodb-org-mongos mongodb-org-server mongodb-org-shell mongodb-org-tools
# The following NEW packages will be installed:
#   mongodb-database-tools mongodb-mongosh mongodb-org mongodb-org-database
#   mongodb-org-database-tools-extra mongodb-org-mongos mongodb-org-server mongodb-org-shell
#   mongodb-org-tools
# 0 upgraded, 9 newly installed, 0 to remove and 52 not upgraded.
# Need to get 162 MB of archives.
# After this operation, 581 MB of additional disk space will be used.
# Get:1 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-database-tools amd64 100.10.0 [46.4 MB]
# Get:2 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-mongosh amd64 2.3.2 [54.1 MB]
# Get:3 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-org-shell amd64 7.0.14 [2,980 B]
# Get:4 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-org-server amd64 7.0.14 [36.5 MB]
# Get:5 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-org-mongos amd64 7.0.14 [25.4 MB]
# Get:6 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-org-database-tools-extra amd64 7.0.14 [7,772 B]
# Get:7 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-org-database amd64 7.0.14 [3,426 B]
# Get:8 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-org-tools amd64 7.0.14 [2,768 B]
# Get:9 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/7.0/multiverse amd64 mongodb-org amd64 7.0.14 [2,800 B]
# Fetched 162 MB in 4s (44.4 MB/s)
# Selecting previously unselected package mongodb-database-tools.
# (Reading database ... 123629 files and directories currently installed.)
# Preparing to unpack .../0-mongodb-database-tools_100.10.0_amd64.deb ...
# Unpacking mongodb-database-tools (100.10.0) ...
# Selecting previously unselected package mongodb-mongosh.
# Preparing to unpack .../1-mongodb-mongosh_2.3.2_amd64.deb ...
# Unpacking mongodb-mongosh (2.3.2) ...
# Selecting previously unselected package mongodb-org-shell.
# Preparing to unpack .../2-mongodb-org-shell_7.0.14_amd64.deb ...
# Unpacking mongodb-org-shell (7.0.14) ...
# Selecting previously unselected package mongodb-org-server.
# Preparing to unpack .../3-mongodb-org-server_7.0.14_amd64.deb ...
# Unpacking mongodb-org-server (7.0.14) ...
# Selecting previously unselected package mongodb-org-mongos.
# Preparing to unpack .../4-mongodb-org-mongos_7.0.14_amd64.deb ...
# Unpacking mongodb-org-mongos (7.0.14) ...
# Selecting previously unselected package mongodb-org-database-tools-extra.
# Preparing to unpack .../5-mongodb-org-database-tools-extra_7.0.14_amd64.deb ...
# Unpacking mongodb-org-database-tools-extra (7.0.14) ...
# Selecting previously unselected package mongodb-org-database.
# Preparing to unpack .../6-mongodb-org-database_7.0.14_amd64.deb ...
# Unpacking mongodb-org-database (7.0.14) ...
# Selecting previously unselected package mongodb-org-tools.
# Preparing to unpack .../7-mongodb-org-tools_7.0.14_amd64.deb ...
# Unpacking mongodb-org-tools (7.0.14) ...
# Selecting previously unselected package mongodb-org.
# Preparing to unpack .../8-mongodb-org_7.0.14_amd64.deb ...
# Unpacking mongodb-org (7.0.14) ...
# Setting up mongodb-mongosh (2.3.2) ...
# Setting up mongodb-org-server (7.0.14) ...
# Adding system user `mongodb' (UID 104) ...
# Adding new user `mongodb' (UID 104) with group `nogroup' ...
# Not creating home directory `/home/mongodb'.
# Adding group `mongodb' (GID 107) ...
# Done.
# Adding user `mongodb' to group `mongodb' ...
# Adding user mongodb to group mongodb
# Done.
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to connect to bus: Host is down
# Setting up mongodb-org-shell (7.0.14) ...
# Setting up mongodb-database-tools (100.10.0) ...
# Setting up mongodb-org-mongos (7.0.14) ...
# Setting up mongodb-org-database-tools-extra (7.0.14) ...
# Setting up mongodb-org-database (7.0.14) ...
# Setting up mongodb-org-tools (7.0.14) ...
# Setting up mongodb-org (7.0.14) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !mkdir /data
# !mkdir /data/db

# %%
import subprocess
subprocess.Popen(["mongod"])
# Out:
# <Popen: returncode: None args: ['mongod']>

# %%
from pymongo import MongoClient
client = MongoClient()
client.list_database_names() # ['admin', 'local']
# Out:
# ['admin', 'config', 'local']

# %% [markdown]
# ## create the db
#
# name our database

# %%
db = client['cloud_purchase_db']

# %% [markdown]
# ## Set up Collections

# %% [markdown]
# drop the collections in case they already exist so we don't duplicate data

# %%
db.drop_collection('customers')
db.drop_collection('products')
#db.drop_collection('orders')
# Out:
# {'nIndexesWas': 1, 'ns': 'cloud_purchase_db.products', 'ok': 1.0}

# %% [markdown]
# do we have any collections?

# %% [markdown]
# ## list collections

# %%
db.list_collection_names()
# Out:
# []

# %%
# Create Faker instance
fake = Faker()

# %% [markdown]
# # Create the data

# %% [markdown]
# ## create customer data
#
# create from 1 to 5 orders (randomly)
# pick a random product id from 1 to 10
# units between 10 and 100
# year from 1 year ago to today

# %%
# Generate customer orders
def gen_orders():

  orders = []
  for i in range(1,random.randint(1, 5)):

      productid = random.randint(1, 10)
      units = random.randint(10, 100)
      if random.random() < 0.1:
          units *= 10
      purchase_date = fake.date_between(start_date='-1y', end_date='today')
      purchase_date = datetime.datetime.combine(purchase_date, datetime.datetime.min.time())

      order = {
          'productid': productid,
          'units': units,
          'purchase_date': purchase_date
      }

      orders.append(order)

  return orders

# %%
gen_orders()
# Out:
# []

# %% [markdown]
# generate 100 customers

# %%
# Generate customers
customers = []
for i in range(100):
    customer = {
        'customerid': i+1,
        'name': fake.name(),
        'email': fake.email(),
        'created' : datetime.datetime.combine(fake.date_between(start_date='-1y', end_date='today'), datetime.datetime.min.time()),
        'phone': [fake.phone_number(),fake.phone_number(),fake.phone_number()],
        'orders' : gen_orders() #this is where we generate orders
    }
    customers.append(customer)

# %%
len(customers)
# Out:
# 100

# %%
customers[0:3]
# Out:
# [{'customerid': 1,
#   'name': 'David Campbell',
#   'email': 'amyrichardson@example.com',
#   'created': datetime.datetime(2024, 3, 28, 0, 0),
#   'phone': ['3618393744', '232.981.6227', '521.536.4875x30210'],
#   'orders': [{'productid': 1,
#     'units': 59,
#     'purchase_date': datetime.datetime(2023, 11, 11, 0, 0)}]},
#  {'customerid': 2,
#   'name': 'Monica Kramer',
#   'email': 'rubioalicia@example.com',
#   'created': datetime.datetime(2024, 4, 23, 0, 0),
#   'phone': ['214.459.0458x694', '457.378.5315x45776', '+1-740-698-5267x96491'],
#   'orders': [{'productid': 8,
#     'units': 19,
#     'purchase_date': datetime.datetime(2024, 5, 6, 0, 0)},
#    {'productid': 1,
#     'units': 16,
#     'purchase_date': datetime.datetime(2024, 3, 23, 0, 0)}]},
#  {'customerid': 3,
#   'name': 'Joshua Ruiz',
#   'email': 'timothygarrett@example.net',
#   'created': datetime.datetime(2024, 8, 29, 0, 0),
#   'phone': ['729.281.5764', '(409)802-5381x74255', '(232)242-2537x4053'],
582fe21a89bed3ac20e1'), ObjectId('6710582fe21a89bed3ac20e2'), ObjectId('6710582fe21a89bed3ac20e3'), ObjectId('6710582fe21a89bed3ac20e4'), ObjectId('6710582fe21a89bed3ac20e5'), ObjectId('6710582fe21a89bed3ac20e6'), ObjectId('6710582fe21a89bed3ac20e7'), ObjectId('6710582fe21a89bed3ac20e8'), ObjectId('6710582fe21a89bed3ac20e9'), ObjectId('6710582fe21a89bed3ac20ea'), ObjectId('6710582fe21a89bed3ac20eb'), ObjectId('6710582fe21a89bed3ac20ec'), ObjectId('6710582fe21a89bed3ac20ed'), ObjectId('6710582fe21a89bed3ac20ee'), ObjectId('6710582fe21a89bed3ac20ef'), ObjectId('6710582fe21a89bed3ac20f0'), ObjectId('6710582fe21a89bed3ac20f1'), ObjectId('6710582fe21a89bed3ac20f2'), ObjectId('6710582fe21a89bed3ac20f3'), ObjectId('6710582fe21a89bed3ac20f4'), ObjectId('6710582fe21a89bed3ac20f5'), ObjectId('6710582fe21a89bed3ac20f6'), ObjectId('6710582fe21a89bed3ac20f7'), ObjectId('6710582fe21a89bed3ac20f8'), ObjectId('6710582fe21a89bed3ac20f9'), ObjectId('6710582fe21a89bed3ac20fa'), ObjectId('6710582fe21a89bed3ac20fb'), ObjectId('6710582fe21a89bed3ac20fc'), ObjectId('6710582fe21a89bed3ac20fd'), ObjectId('6710582fe21a89bed3ac20fe'), ObjectId('6710582fe21a89bed3ac20ff'), ObjectId('6710582fe21a89bed3ac2100'), ObjectId('6710582fe21a89bed3ac2101'), ObjectId('6710582fe21a89bed3ac2102'), ObjectId('6710582fe21a89bed3ac2103'), ObjectId('6710582fe21a89bed3ac2104'), ObjectId('6710582fe21a89bed3ac2105'), ObjectId('6710582fe21a89bed3ac2106'), ObjectId('6710582fe21a89bed3ac2107'), ObjectId('6710582fe21a89bed3ac2108'), ObjectId('6710582fe21a89bed3ac2109'), ObjectId('6710582fe21a89bed3ac210a')], acknowledged=True)

# %% [markdown]
# ## create products data

# %%
# Generate products
products = []
for i in range(10):
    product = {
        'productid': i+1,
        'category': random.choice(['Electronics', 'Clothing', 'Books', 'Home']),
        'price': random.randint(1, 100)
    }
    products.append(product)

# %%
products[0:3]
# Out:
# [{'productid': 1, 'category': 'Clothing', 'price': 19},
#  {'productid': 2, 'category': 'Home', 'price': 62},
#  {'productid': 3, 'category': 'Home', 'price': 7}]

# %% [markdown]
# put the 10 products into the database

# %%
# Insert products into MongoDB
db.products.insert_many(products)
# Out:
# InsertManyResult([ObjectId('67105837e21a89bed3ac210b'), ObjectId('67105837e21a89bed3ac210c'), ObjectId('67105837e21a89bed3ac210d'), ObjectId('67105837e21a89bed3ac210e'), ObjectId('67105837e21a89bed3ac210f'), ObjectId('67105837e21a89bed3ac2110'), ObjectId('67105837e21a89bed3ac2111'), ObjectId('67105837e21a89bed3ac2112'), ObjectId('67105837e21a89bed3ac2113'), ObjectId('67105837e21a89bed3ac2114')], acknowledged=True)

# %%
db.list_collection_names() # list collections
# Out:
# ['customers', 'products']

# %% [markdown]
# loop through collections and count the number of documents

# %%
for collection_name in db.list_collection_names():
  collection = db.get_collection(collection_name)
  print(f'{collection_name}:{collection.count_documents({})}')
# Out:
# customers:100
# products:10

# %% [markdown]
# # Querying

# %% [markdown]
# ## Customers
#
# Find all customers.

# %%
for document in db.customers.find({}):
  print(document)
# Out:
# {'_id': ObjectId('6710582fe21a89bed3ac20a7'), 'customerid': 1, 'name': 'David Campbell', 'email': 'amyrichardson@example.com', 'created': datetime.datetime(2024, 3, 28, 0, 0), 'phone': ['3618393744', '232.981.6227', '521.536.4875x30210'], 'orders': [{'productid': 1, 'units': 59, 'purchase_date': datetime.datetime(2023, 11, 11, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20a8'), 'customerid': 2, 'name': 'Monica Kramer', 'email': 'rubioalicia@example.com', 'created': datetime.datetime(2024, 4, 23, 0, 0), 'phone': ['214.459.0458x694', '457.378.5315x45776', '+1-740-698-5267x96491'], 'orders': [{'productid': 8, 'units': 19, 'purchase_date': datetime.datetime(2024, 5, 6, 0, 0)}, {'productid': 1, 'units': 16, 'purchase_date': datetime.datetime(2024, 3, 23, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20a9'), 'customerid': 3, 'name': 'Joshua Ruiz', 'email': 'timothygarrett@example.net', 'created': datetime.datetime(2024, 8, 29, 0, 0), 'phone': ['729.281.5764', '(409)802-5381x74255', '(232)242-2537x4053'], 'orders': [{'productid': 9, 'units': 51, 'purchase_date': datetime.datetime(2024, 7, 1, 0, 0)}, {'productid': 1, 'units': 73, 'purchase_date': datetime.datetime(2024, 2, 15, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20aa'), 'customerid': 4, 'name': 'Ronald Anderson', 'email': 'nortonricky@example.com', 'created': datetime.datetime(2024, 1, 1, 0, 0), 'phone': ['(532)948-0956x416', '855.323.2964x83837', '934.613.3357'], 'orders': [{'productid': 1, 'units': 97, 'purchase_date': datetime.datetime(2024, 9, 10, 0, 0)}, {'productid': 4, 'units': 66, 'purchase_date': datetime.datetime(2024, 7, 4, 0, 0)}, {'productid': 2, 'units': 53, 'purchase_date': datetime.datetime(2024, 7, 13, 0, 0)}, {'productid': 2, 'units': 930, 'purchase_date': datetime.datetime(2024, 1, 14, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20ab'), 'customerid': 5, 'name': 'James Nguyen', 'email': 'alexandrapittman@example.com', 'created': datetime.datetime(2023, 12, 5, 0, 0), 'phone': ['837-609-4741x640', '(556)599-7728', '230.312.6799x9456'], 'orders': [{'productid': 2, 'units': 840, 'purchase_date': datetime.datetime(2024, 4, 28, 0, 0)}, {'productid': 6, 'units': 74, 'purchase_date': datetime.datetime(2024, 3, 1, 0, 0)}, {'productid': 8, 'units': 16, 'purchase_date': datetime.datetime(2024, 3, 15, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20ac'), 'customerid': 6, 'name': 'Cody Moreno', 'email': 'clifford91@example.com', 'created': datetime.datetime(2024, 6, 5, 0, 0), 'phone': ['9592143917', '(891)623-1002x2949', '893.936.7695'], 'orders': [{'productid': 7, 'units': 18, 'purchase_date': datetime.datetime(2024, 8, 23, 0, 0)}, {'productid': 3, 'units': 70, 'purchase_date': datetime.datetime(2024, 9, 29, 0, 0)}, {'productid': 3, 'units': 79, 'purchase_date': datetime.datetime(2024, 6, 4, 0, 0)}, {'productid': 2, 'units': 50, 'purchase_date': datetime.datetime(2024, 10, 12, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac
 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20bc'), 'customerid': 22, 'name': 'Tabitha Brennan', 'email': 'hallchristopher@example.net', 'created': datetime.datetime(2023, 10, 24, 0, 0), 'phone': ['984-361-9256x37830', '960-857-5810', '001-370-318-7359x674'], 'orders': [{'productid': 9, 'units': 16, 'purchase_date': datetime.datetime(2024, 10, 1, 0, 0)}, {'productid': 6, 'units': 82, 'purchase_date': datetime.datetime(2024, 6, 18, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20bd'), 'customerid': 23, 'name': 'Chris Andrews', 'email': 'pricedenise@example.net', 'created': datetime.datetime(2023, 12, 26, 0, 0), 'phone': ['001-911-496-4051x61201', '(520)861-3775', '784.620.2730'], 'orders': [{'productid': 4, 'units': 55, 'purchase_date': datetime.datetime(2023, 11, 20, 0, 0)}, {'productid': 6, 'units': 350, 'purchase_date': datetime.datetime(2024, 6, 22, 0, 0)}, {'productid': 10, 'units': 23, 'purchase_date': datetime.datetime(2024, 6, 5, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20be'), 'customerid': 24, 'name': 'Mason Peterson', 'email': 'martinezjulia@example.org', 'created': datetime.datetime(2024, 8, 5, 0, 0), 'phone': ['001-560-389-1039x365', '702-701-5226x459', '(580)999-9722x6697'], 'orders': [{'productid': 9, 'units': 79, 'purchase_date': datetime.datetime(2024, 5, 3, 0, 0)}, {'productid': 9, 'units': 11, 'purchase_date': datetime.datetime(2024, 8, 1, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20bf'), 'customerid': 25, 'name': 'Seth York', 'email': 'xsingleton@example.org', 'created': datetime.datetime(2024, 1, 6, 0, 0), 'phone': ['543.260.5751x461', '883.395.6925x500', '534-713-5529x2431'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20c0'), 'customerid': 26, 'name': 'Kendra Mendez DVM', 'email': 'davidlewis@example.com', 'created': datetime.datetime(2024, 4, 2, 0, 0), 'phone': ['+1-660-377-4099x625', '(448)881-5897', '506.294.8935x16546'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20c1'), 'customerid': 27, 'name': 'Benjamin Odom', 'email': 'qsmith@example.com', 'created': datetime.datetime(2024, 9, 23, 0, 0), 'phone': ['(832)925-0118x4417', '589-615-9687x418', '561.674.2352'], 'orders': [{'productid': 6, 'units': 23, 'purchase_date': datetime.datetime(2024, 8, 27, 0, 0)}, {'productid': 10, 'units': 180, 'purchase_date': datetime.datetime(2024, 5, 12, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20c2'), 'customerid': 28, 'name': 'Stephanie Roberson', 'email': 'rileyallison@example.com', 'created': datetime.datetime(2024, 3, 5, 0, 0), 'phone': ['+1-850-419-5708x547', '950.983.4363', '(340)448-1527'], 'orders': [{'productid': 10, 'units': 37, 'purchase_date': datetime.datetime(2023, 11, 28, 0, 0)}, {'productid': 3, 'units': 35, 'purchase_date': datetime.datetime(2024, 6, 27, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20c3'), 'customerid': 29, 'name': 'Meredith Peters', 'email': 'garciadiane@example.org', 'created': datetime.datetime(2024, 7, 8, 0, 0), 'phone': ['406-553-9349', '+1-498-445-8994x995', '+1-336-788-2969x328'], 'orders': [{'productid': 9, 'units': 57, 'purchase_date': datetime.datetime(2024, 8, 8, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20c4'), 'customerid': 30, 'name': 'Mary Ward', 'email': 'qrivers@example.com', 'created': datetime.datetime(2024, 6, 20, 0, 0), 'phone': ['7826772580', '+1-395-684-7386x2336', '(219)352-2472x8190'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20c5'), 'customerid': 31, 'name': 'Christopher Morse', 'email': 'gina80@example.com', 'created': datetime.datetime(2024, 8, 21, 0, 0), 'phone': ['6208061504', '911.451.2309x9203', '377-582-1728'], 'orders': [{'productid': 2, 'units': 33, 'purchase_date': datetime.datetime(2024, 9, 5, 0, 0)}, {'productid': 3, 'units': 10, 'purchase_date': datetime.datetime(2023, 12, 9, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20c6'), 'customerid': 32, 'name': 'Steven Nelson', 'email': 'melanie23@example.org', 'created': datetime.datetime(2024, 5, 30, 0, 0), 'phone': ['570-919-9520', '+1-521-212-7388', '439.697.7214x833'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20c7'), 'customerid': 33, 'name': 'Brent Ware', 'email': 'walkertimothy@example.com', 'created': datetime.datetime(2024, 1, 10, 0, 0), 'phone': ['+1-409-415-1392', '862.920.9202', '(980)440-9527x60450'], 'orders': [{'productid': 3, 'units': 16, 'purchase_date': datetime.datetime(2024, 10, 5, 0, 0)}, {'productid': 2, 'units': 48, 'purchase_date': datetime.datetime(2024, 10, 1, 0, 0)}, {'productid': 10, 'units': 29, 'purchase_date': datetime.datetime(2024, 1, 17, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20c8'), 'customerid': 34, 'name': 'Craig Lopez', 'email': 'terry80@example.net', 'created': datetime.datetime(2024, 9, 1, 0, 0), 'phone': ['+1-475-757-8652x928', '001-645-364-7368x6170', '819.385.1862x4228'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20c9'), 'customerid': 35, 'name': 'Robert Barnes', 'email': 'kelly39@example.com', 'created': datetime.datetime(2024, 7, 23, 0, 0), 'phone': ['(745)796-5199', '487-629-0034', '+1-386-637-4068x017'], 'orders': [{'productid': 4, 'units': 68, 'purchase_date': datetime.datetime(2024, 10, 5, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20ca'), 'customerid': 36, 'name': 'Nathan Brown', 'email': 'brusso@example.org', 'created': datetime.datetime(2024, 6, 30, 0, 0), 'phone': ['613-925-4019x8057', '(881)983-4820x747', '(871)726-0101x83255'], 'orders': [{'productid': 3, 'units': 910, 'purchase_date': datetime.datetime(2023, 11, 14, 0, 0)}, {'productid': 6, 'units': 68, 'purchase_date': datetime.datetime(2024, 9, 5, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20cb'), 'customerid': 37, 'name': 'Tina Hill', 'email': 'leejessica@example.net', 'created': datetime.datetime(2024, 4, 29, 0, 0), 'phone': ['488-509-0759', '+1-309-453-4059x0010', '834-455-2098x669'], 'orders': [{'productid': 4, 'units': 170, 'purchase_date': datetime.datetime(2024, 2, 13, 0, 0)}, {'productid': 2, 'units': 160, 'purchase_date': datetime.datetime(2024, 4, 21, 0, 0)}, {'productid': 5, 'units': 35, 'purchase_date': datetime.datetime(2023, 11, 30, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac
 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20d4'), 'customerid': 46, 'name': 'Bryan Smith', 'email': 'duartejohn@example.net', 'created': datetime.datetime(2024, 3, 7, 0, 0), 'phone': ['(650)497-4511x245', '420-832-4184x711', '9409082041'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20d5'), 'customerid': 47, 'name': 'Heather Patton', 'email': 'obrienjimmy@example.com', 'created': datetime.datetime(2024, 5, 23, 0, 0), 'phone': ['354-364-1532x3385', '(314)927-6699', '2414950998'], 'orders': [{'productid': 9, 'units': 92, 'purchase_date': datetime.datetime(2024, 1, 12, 0, 0)}, {'productid': 5, 'units': 18, 'purchase_date': datetime.datetime(2024, 6, 10, 0, 0)}, {'productid': 6, 'units': 37, 'purchase_date': datetime.datetime(2024, 5, 22, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20d6'), 'customerid': 48, 'name': 'Hunter Medina', 'email': 'alexanderali@example.org', 'created': datetime.datetime(2024, 6, 4, 0, 0), 'phone': ['794.715.8546', '804-888-4589x99618', '+1-674-716-1820'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20d7'), 'customerid': 49, 'name': 'Ryan Hernandez', 'email': 'bettyphillips@example.net', 'created': datetime.datetime(2024, 6, 19, 0, 0), 'phone': ['+1-320-319-5639', '630.849.1615x869', '(808)369-6793x85421'], 'orders': [{'productid': 10, 'units': 34, 'purchase_date': datetime.datetime(2024, 5, 13, 0, 0)}, {'productid': 2, 'units': 600, 'purchase_date': datetime.datetime(2024, 2, 22, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20d8'), 'customerid': 50, 'name': 'Jerry Underwood', 'email': 'edwardalvarez@example.net', 'created': datetime.datetime(2024, 9, 28, 0, 0), 'phone': ['398.357.9507x549', '6804170667', '+1-604-932-2150'], 'orders': [{'productid': 8, 'units': 86, 'purchase_date': datetime.datetime(2024, 4, 24, 0, 0)}, {'productid': 9, 'units': 40, 'purchase_date': datetime.datetime(2024, 7, 5, 0, 0)}, {'productid': 3, 'units': 530, 'purchase_date': datetime.datetime(2024, 4, 8, 0, 0)}, {'productid': 1, 'units': 87, 'purchase_date': datetime.datetime(2024, 9, 5, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20d9'), 'customerid': 51, 'name': 'Brandon Miller', 'email': 'jennifer19@example.net', 'created': datetime.datetime(2024, 9, 27, 0, 0), 'phone': ['+1-555-577-4033', '4492098974', '(981)612-1675'], 'orders': [{'productid': 2, 'units': 61, 'purchase_date': datetime.datetime(2024, 4, 12, 0, 0)}, {'productid': 2, 'units': 25, 'purchase_date': datetime.datetime(2024, 8, 23, 0, 0)}, {'productid': 4, 'units': 11, 'purchase_date': datetime.datetime(2024, 5, 29, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20da'), 'customerid': 52, 'name': 'Mark Peck', 'email': 'stephanietrujillo@example.com', 'created': datetime.datetime(2024, 1, 9, 0, 0), 'phone': ['215-270-9636x0503', '(333)644-6684x7666', '555-971-9908x5366'], 'orders': [{'productid': 6, 'units': 86, 'purchase_date': datetime.datetime(2023, 12, 28, 0, 0)}, {'productid': 9, 'units': 18, 'purchase_date': datetime.datetime(2024, 7, 24, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20db'), 'customerid': 53, 'name': 'Joanna Brown', 'email': 'smithjonathan@example.net', 'created': datetime.datetime(2024, 1, 27, 0, 0), 'phone': ['9827189890', '897-715-3257', '692.785.3082'], 'orders': [{'productid': 10, 'units': 39, 'purchase_date': datetime.datetime(2024, 9, 17, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20dc'), 'customerid': 54, 'name': 'Richard Lucas', 'email': 'rfrench@example.org', 'created': datetime.datetime(2024, 3, 20, 0, 0), 'phone': ['428.653.0857', '686.754.7884', '001-878-980-2415x21648'], 'orders': [{'productid': 7, 'units': 13, 'purchase_date': datetime.datetime(2024, 9, 18, 0, 0)}, {'productid': 9, 'units': 14, 'purchase_date': datetime.datetime(2024, 7, 9, 0, 0)}, {'productid': 7, 'units': 100, 'purchase_date': datetime.datetime(2024, 2, 7, 0, 0)}, {'productid': 3, 'units': 93, 'purchase_date': datetime.datetime(2024, 4, 10, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20dd'), 'customerid': 55, 'name': 'Christine Holmes', 'email': 'robertawilliams@example.com', 'created': datetime.datetime(2024, 1, 19, 0, 0), 'phone': ['001-701-943-3119x042', '873-488-8981x950', '(455)691-0168'], 'orders': [{'productid': 1, 'units': 62, 'purchase_date': datetime.datetime(2023, 10, 19, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20de'), 'customerid': 56, 'name': 'Jennifer Thomas', 'email': 'stephanie91@example.org', 'created': datetime.datetime(2024, 10, 1, 0, 0), 'phone': ['(220)976-0146x267', '557-253-6389x409', '001-348-667-0155x6098'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20df'), 'customerid': 57, 'name': 'Michelle Lawson', 'email': 'sarah32@example.net', 'created': datetime.datetime(2024, 2, 14, 0, 0), 'phone': ['+1-526-697-1270x15551', '001-520-218-3776x272', '+1-820-300-9078x695'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20e0'), 'customerid': 58, 'name': 'Leslie Burnett', 'email': 'fhurley@example.com', 'created': datetime.datetime(2023, 11, 1, 0, 0), 'phone': ['483.779.3565x4307', '+1-453-799-8127x5759', '818-829-0946'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20e1'), 'customerid': 59, 'name': 'Austin Harper', 'email': 'rbenson@example.net', 'created': datetime.datetime(2024, 7, 18, 0, 0), 'phone': ['(550)443-9943x4845', '382.387.1119x37172', '001-355-481-0774'], 'orders': [{'productid': 2, 'units': 78, 'purchase_date': datetime.datetime(2024, 2, 16, 0, 0)}, {'productid': 8, 'units': 44, 'purchase_date': datetime.datetime(2024, 1, 22, 0, 0)}, {'productid': 3, 'units': 99, 'purchase_date': datetime.datetime(2023, 11, 14, 0, 0)}, {'productid': 9, 'units': 71, 'purchase_date': datetime.datetime(2024, 6, 14, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20e2'), 'customerid': 60, 'name': 'Heather Cooper', 'email': 'samuelreynolds@example.org', 'created': datetime.datetime(2024, 10, 12, 0, 0), 'phone': ['001-984-751-2968x87956', '001-222-401-5750', '+1-994-693-8694x1792'], 'orders': [{'productid': 10, 'units': 35, 'purchase_date': datetime.datetime(2024, 4, 19, 0, 0)}, {'productid': 2, 'units': 62, 'purchase_date': datetime.datetime(2024, 7, 14, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac
 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20ea'), 'customerid': 68, 'name': 'Michelle Mayer', 'email': 'carpenterkimberly@example.com', 'created': datetime.datetime(2024, 6, 28, 0, 0), 'phone': ['+1-711-580-0878x387', '(666)683-1917x355', '(732)436-3937'], 'orders': [{'productid': 9, 'units': 52, 'purchase_date': datetime.datetime(2023, 12, 15, 0, 0)}, {'productid': 5, 'units': 29, 'purchase_date': datetime.datetime(2024, 10, 1, 0, 0)}, {'productid': 7, 'units': 62, 'purchase_date': datetime.datetime(2024, 5, 3, 0, 0)}, {'productid': 8, 'units': 640, 'purchase_date': datetime.datetime(2024, 8, 3, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20eb'), 'customerid': 69, 'name': 'Tara Chavez', 'email': 'greenbrittney@example.net', 'created': datetime.datetime(2024, 1, 11, 0, 0), 'phone': ['244-552-7174x17211', '286-886-1872', '001-855-491-7155x782'], 'orders': [{'productid': 9, 'units': 21, 'purchase_date': datetime.datetime(2024, 3, 8, 0, 0)}, {'productid': 2, 'units': 88, 'purchase_date': datetime.datetime(2023, 12, 11, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20ec'), 'customerid': 70, 'name': 'John Griffin', 'email': 'jamesrobert@example.org', 'created': datetime.datetime(2024, 2, 23, 0, 0), 'phone': ['(535)208-4682x181', '271-422-0239x81286', '(388)883-8984x5626'], 'orders': [{'productid': 6, 'units': 64, 'purchase_date': datetime.datetime(2024, 1, 21, 0, 0)}, {'productid': 1, 'units': 55, 'purchase_date': datetime.datetime(2024, 9, 12, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20ed'), 'customerid': 71, 'name': 'Stephen Perry', 'email': 'pbailey@example.org', 'created': datetime.datetime(2024, 2, 10, 0, 0), 'phone': ['(482)934-3733', '001-882-857-0596x043', '(368)443-6743x2682'], 'orders': [{'productid': 9, 'units': 49, 'purchase_date': datetime.datetime(2024, 4, 12, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20ee'), 'customerid': 72, 'name': 'Diane Gomez', 'email': 'rodriguezchelsea@example.org', 'created': datetime.datetime(2024, 2, 19, 0, 0), 'phone': ['519-609-6144x75391', '+1-978-478-5610x48045', '(883)827-4388'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20ef'), 'customerid': 73, 'name': 'John Shelton', 'email': 'crystalpatel@example.net', 'created': datetime.datetime(2024, 8, 21, 0, 0), 'phone': ['937.610.7012x6769', '398-452-3419x5437', '794.564.0467x448'], 'orders': [{'productid': 4, 'units': 26, 'purchase_date': datetime.datetime(2024, 2, 18, 0, 0)}, {'productid': 4, 'units': 56, 'purchase_date': datetime.datetime(2024, 1, 22, 0, 0)}, {'productid': 1, 'units': 40, 'purchase_date': datetime.datetime(2023, 11, 12, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20f0'), 'customerid': 74, 'name': 'Catherine Clayton', 'email': 'heather50@example.org', 'created': datetime.datetime(2023, 10, 26, 0, 0), 'phone': ['+1-429-805-0784x642', '+1-452-281-0865', '524.818.3134'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20f1'), 'customerid': 75, 'name': 'Patty English', 'email': 'randerson@example.net', 'created': datetime.datetime(2023, 12, 5, 0, 0), 'phone': ['424-559-3223', '(613)512-2237x47191', '001-526-924-3964x638'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20f2'), 'customerid': 76, 'name': 'Alexis Phillips', 'email': 'sarah29@example.net', 'created': datetime.datetime(2024, 3, 19, 0, 0), 'phone': ['929-259-4050x54711', '4726660070', '001-988-543-2572x2714'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20f3'), 'customerid': 77, 'name': 'Sylvia Castro', 'email': 'annedwards@example.net', 'created': datetime.datetime(2024, 5, 14, 0, 0), 'phone': ['934.708.7348', '326-438-2770', '(655)967-7675x09879'], 'orders': [{'productid': 9, 'units': 52, 'purchase_date': datetime.datetime(2024, 1, 15, 0, 0)}, {'productid': 6, 'units': 47, 'purchase_date': datetime.datetime(2024, 1, 11, 0, 0)}, {'productid': 9, 'units': 38, 'purchase_date': datetime.datetime(2024, 8, 21, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20f4'), 'customerid': 78, 'name': 'Michelle Cook', 'email': 'npeterson@example.net', 'created': datetime.datetime(2024, 3, 21, 0, 0), 'phone': ['461-610-9296x9322', '+1-962-588-7653x8491', '001-240-307-5211x394'], 'orders': [{'productid': 6, 'units': 540, 'purchase_date': datetime.datetime(2024, 7, 14, 0, 0)}, {'productid': 10, 'units': 24, 'purchase_date': datetime.datetime(2023, 12, 30, 0, 0)}, {'productid': 7, 'units': 66, 'purchase_date': datetime.datetime(2023, 12, 15, 0, 0)}, {'productid': 6, 'units': 16, 'purchase_date': datetime.datetime(2023, 11, 16, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20f5'), 'customerid': 79, 'name': 'Anthony Mitchell', 'email': 'tsmith@example.net', 'created': datetime.datetime(2023, 12, 29, 0, 0), 'phone': ['(335)672-8929x7465', '+1-881-306-6784', '+1-413-460-1105x60808'], 'orders': [{'productid': 1, 'units': 72, 'purchase_date': datetime.datetime(2024, 2, 10, 0, 0)}, {'productid': 5, 'units': 81, 'purchase_date': datetime.datetime(2023, 12, 10, 0, 0)}, {'productid': 2, 'units': 60, 'purchase_date': datetime.datetime(2024, 3, 15, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20f6'), 'customerid': 80, 'name': 'Shawn Mcintyre', 'email': 'pwright@example.org', 'created': datetime.datetime(2024, 3, 23, 0, 0), 'phone': ['(400)416-1732x665', '324-278-8930x132', '317-916-5542'], 'orders': [{'productid': 8, 'units': 48, 'purchase_date': datetime.datetime(2024, 5, 13, 0, 0)}, {'productid': 4, 'units': 97, 'purchase_date': datetime.datetime(2024, 10, 12, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20f7'), 'customerid': 81, 'name': 'Michael Burton', 'email': 'grahamnathan@example.com', 'created': datetime.datetime(2024, 2, 5, 0, 0), 'phone': ['766-385-4333', '001-657-968-0697x83945', '(429)234-4643'], 'orders': [{'productid': 9, 'units': 74, 'purchase_date': datetime.datetime(2024, 2, 15, 0, 0)}, {'productid': 3, 'units': 70, 'purchase_date': datetime.datetime(2024, 4, 12, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20f8'), 'customerid': 82, 'name': 'Dalton Salinas', 'email': 'dalecastillo@example.net', 'created': datetime.datetime(2023, 11, 22, 0, 0), 'phone': ['(625)836-2201', '812.520.6342', '(990)919-9233x9266'], 'orders': [{'productid': 8, 'units': 28, 'purchase_date': datetime.datetime(2024, 2, 17, 0, 0)}, {'productid': 1, 'units': 11, 'purchase_date': datetime.datetime(2024, 8, 12, 0, 0)}, {'productid': 10, 'units': 29, 'purchase_date': datetime.datetime(2024, 2, 10, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20f9'), 'customerid': 83, 'name': 'Christopher Miles', 'email': 'rebecca26@example.org', 'created': datetime.datetime(2024, 5, 21, 0, 0), 'phone': ['+1-609-383-1831', '489.470.3464', '+1-916-780-0039'], 'orders': [{'productid': 10, 'units': 79, 'purchase_date': datetime.datetime(2024, 9, 10, 0, 0)}, {'productid': 7, 'units': 89, 'purchase_date': datetime.datetime(2023, 12, 11, 0, 0)}, {'productid': 5, 'units': 79, 'purchase_date': datetime.datetime(2023, 11, 5, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20fa'), 'customerid': 84, 'name': 'Mark Price', 'email': 'jellis@example.org', 'created': datetime.datetime(2024, 2, 20, 0, 0), 'phone': ['670-380-9890', '794.502.2201x47154', '001-398-685-8524x848'], 'orders': [{'productid': 3, 'units': 24, 'purchase_date': datetime.datetime(2023, 11, 15, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20fb'), 'customerid': 85, 'name': 'Nicole Shannon', 'email': 'jameslong@example.com', 'created': datetime.datetime(2024, 10, 14, 0, 0), 'phone': ['+1-467-527-0956', '001-797-317-3306x360', '+1-518-886-4910x080'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20fc'), 'customerid': 86, 'name': 'Angela Marshall', 'email': 'baldwinjames@example.net', 'created': datetime.datetime(2024, 8, 6, 0, 0), 'phone': ['(762)770-5383x578', '(978)254-2363x10706', '+1-349-658-9759x926'], 'orders': [{'productid': 10, 'units': 55, 'purchase_date': datetime.datetime(2023, 12, 21, 0, 0)}, {'productid': 10, 'units': 55, 'purchase_date': datetime.datetime(2024, 6, 24, 0, 0)}, {'productid': 8, 'units': 61, 'purchase_date': datetime.datetime(2024, 5, 11, 0, 0)}, {'productid': 2, 'units': 62, 'purchase_date': datetime.datetime(2024, 7, 23, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20fd'), 'customerid': 87, 'name': 'Madison Wong', 'email': 'hartmanallen@example.org', 'created': datetime.datetime(2024, 7, 11, 0, 0), 'phone': ['(548)542-0848', '(656)390-0113x91817', '496.462.5953'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac20fe'), 'customerid': 88, 'name': 'Allen Schmidt', 'email': 'davidcarey@example.org', 'created': datetime.datetime(2024, 7, 28, 0, 0), 'phone': ['417.741.3995x480', '+1-581-693-1216x8892', '+1-552-379-6387x572'], 'orders': [{'productid': 2, 'units': 76, 'purchase_date': datetime.datetime(2023, 12, 16, 0, 0)}, {'productid': 6, 'units': 70, 'purchase_date': datetime.datetime(2024, 3, 16, 0, 0)}, {'productid': 2, 'units': 75, 'purchase_date': datetime.datetime(2023, 10, 24, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac20ff'), 'customerid': 89, 'name': 'Alexis Osborn', 'email': 'zadams@example.net', 'created': datetime.datetime(2024, 8, 18, 0, 0), 'phone': ['001-984-418-5695x5566', '(646)736-5604', '001-381-629-2595x617'], 'orders': [{'productid': 8, 'units': 67, 'purchase_date': datetime.datetime(2024, 1, 29, 0, 0)}, {'productid': 9, 'units': 19, 'purchase_date': datetime.datetime(2023, 12, 31, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac2100'), 'customerid': 90, 'name': 'Steven Bradley', 'email': 'yfriedman@example.net', 'created': datetime.datetime(2023, 12, 6, 0, 0), 'phone': ['263.333.5480x52822', '833-887-9681x653', '638.941.3410'], 'orders': [{'productid': 10, 'units': 68, 'purchase_date': datetime.datetime(2024, 1, 12, 0, 0)}, {'productid': 10, 'units': 18, 'purchase_date': datetime.datetime(2024, 3, 10, 0, 0)}, {'productid': 10, 'units': 66, 'purchase_date': datetime.datetime(2024, 10, 4, 0, 0)}, {'productid': 1, 'units': 30, 'purchase_date': datetime.datetime(2024, 7, 25, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac2101'), 'customerid': 91, 'name': 'Lisa Johnson', 'email': 'garrettstephen@example.com', 'created': datetime.datetime(2024, 7, 13, 0, 0), 'phone': ['001-807-761-5645x65625', '(983)437-1954', '(510)779-2081'], 'orders': []}
# {'_id': ObjectId('6710582fe21a89bed3ac2102'), 'customerid': 92, 'name': 'Maria Munoz', 'email': 'ybeck@example.com', 'created': datetime.datetime(2024, 3, 2, 0, 0), 'phone': ['(232)895-3795x557', '900-850-6643x1342', '(522)327-5765x8222'], 'orders': [{'productid': 5, 'units': 20, 'purchase_date': datetime.datetime(2024, 1, 12, 0, 0)}, {'productid': 9, 'units': 51, 'purchase_date': datetime.datetime(2023, 11, 24, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac2103'), 'customerid': 93, 'name': 'Monica Rivera', 'email': 'jamespearson@example.net', 'created': datetime.datetime(2024, 6, 30, 0, 0), 'phone': ['(248)831-1738x674', '(835)429-7817x063', '(931)995-0002x75455'], 'orders': [{'productid': 3, 'units': 23, 'purchase_date': datetime.datetime(2023, 11, 3, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac2104'), 'customerid': 94, 'name': 'Kevin Brooks', 'email': 'brownmanuel@example.net', 'created': datetime.datetime(2024, 3, 18, 0, 0), 'phone': ['967-229-2970', '001-289-903-0857x4269', '9802110602'], 'orders': [{'productid': 10, 'units': 84, 'purchase_date': datetime.datetime(2024, 10, 14, 0, 0)}, {'productid': 2, 'units': 26, 'purchase_date': datetime.datetime(2024, 1, 23, 0, 0)}, {'productid': 8, 'units': 70, 'purchase_date': datetime.datetime(2024, 6, 28, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac2105'), 'customerid': 95, 'name': 'Kelly Johnson', 'email': 'lambertsandra@example.net', 'created': datetime.datetime(2024, 2, 11, 0, 0), 'phone': ['732.352.9308', '001-538-237-1402x09655', '001-739-739-9252'], 'orders': [{'productid': 1, 'units': 74, 'purchase_date': datetime.datetime(2024, 7, 8, 0, 0)}, {'productid': 10, 'units': 87, 'purchase_date': datetime.datetime(2023, 12, 20, 0, 0)}, {'productid': 7, 'units': 69, 'purchase_date': datetime.datetime(2024, 4, 19, 0, 0)}, {'productid': 1, 'units': 51, 'purchase_date': datetime.datetime(2024, 10, 3, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac2106'), 'customerid': 96, 'name': 'Diana Campbell', 'email': 'randyevans@example.org', 'created': datetime.datetime(2024, 1, 5, 0, 0), 'phone': ['(741)216-3141', '(395)462-4423', '6084839522'], 'orders': [{'productid': 5, 'units': 94, 'purchase_date': datetime.datetime(2024, 1, 29, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac2107'), 'customerid': 97, 'name': 'Sarah Osborne', 'email': 'gary47@example.com', 'created': datetime.datetime(2023, 12, 21, 0, 0), 'phone': ['(276)211-1590x8366', '001-622-988-9092', '(979)644-0704'], 'orders': [{'productid': 1, 'units': 400, 'purchase_date': datetime.datetime(2024, 9, 26, 0, 0)}, {'productid': 4, 'units': 77, 'purchase_date': datetime.datetime(2024, 8, 27, 0, 0)}, {'productid': 7, 'units': 26, 'purchase_date': datetime.datetime(2024, 9, 9, 0, 0)}, {'productid': 10, 'units': 360, 'purchase_date': datetime.datetime(2024, 1, 30, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac2108'), 'customerid': 98, 'name': 'Tiffany Johnson', 'email': 'erica65@example.org', 'created': datetime.datetime(2024, 1, 30, 0, 0), 'phone': ['566.341.0858x486', '+1-558-919-6681x53431', '327.996.0763x39937'], 'orders': [{'productid': 9, 'units': 34, 'purchase_date': datetime.datetime(2023, 11, 13, 0, 0)}, {'productid': 1, 'units': 410, 'purchase_date': datetime.datetime(2024, 4, 15, 0, 0)}, {'productid': 1, 'units': 66, 'purchase_date': datetime.datetime(2024, 4, 3, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac2109'), 'customerid': 99, 'name': 'Andrew Flores', 'email': 'ashley34@example.com', 'created': datetime.datetime(2024, 2, 23, 0, 0), 'phone': ['(318)432-3687x9413', '+1-830-528-2521x4693', '+1-254-383-8342x9697'], 'orders': [{'productid': 8, 'units': 59, 'purchase_date': datetime.datetime(2024, 7, 18, 0, 0)}]}
# {'_id': ObjectId('6710582fe21a89bed3ac210a'), 'customerid': 100, 'name': 'Gene Sanchez', 'email': 'reginawalters@example.com', 'created': datetime.datetime(2024, 2, 8, 0, 0), 'phone': ['281.802.2167x7227', '525-951-3361x6388', '001-803-362-3195x70417'], 'orders': [{'productid': 10, 'units': 34, 'purchase_date': datetime.datetime(2024, 8, 5, 0, 0)}, {'productid': 5, 'units': 740, 'purchase_date': datetime.datetime(2024, 1, 23, 0, 0)}, {'productid': 4, 'units': 70, 'purchase_date': datetime.datetime(2023, 12, 31, 0, 0)}, {'productid': 7, 'units': 32, 'purchase_date': datetime.datetime(2024, 6, 30, 0, 0)}]}

# %% [markdown]
# find customerid 76

# %%
import pprint

# %%
for document in db.customers.find({'customerid':76}):
  print(pprint.pprint(document))

# %%
for document in db.customers.find({'$or':[{'customerid':76},{'customerid':6}]}):
  print(pprint.pprint(document))

# %%
for document in db.customers.find({'customerid': {'$in': [76,6]}}):
  print(pprint.pprint(document))

# %% [markdown]
# find customers created in august 2023

# %%
from datetime import datetime

# %%
august_customers = db.customers.find({
    "created": {
        "$gte": datetime(2023, 8, 1),
        "$lt": datetime(2023, 9, 1)
    }
})

for customer in august_customers:
    print(customer)  # Or handle each document as needed

# %% [markdown]
# ## Products
#
# find all products

# %%
for document in db.products.find({}):
  print(document)

# %% [markdown]
# find all products with prices less than 40

# %%
for document in db.products.find({'price': {'$lt':40}}):
  print(document)

# %% [markdown]
# find all products with category clothing
#
# the find method returns a cursor that lazily loads the result set in batches as we iterate over them.

# %%
db.products.find({'category': 'Clothing'})

# %%
for document in db.products.find({'category': 'Clothing'}):
  print(document)

# %% [markdown]
# not equal query

# %%
for document in db.products.find({"category": {"$ne": "Clothing"}}):
  print(document)

# %% [markdown]
# the equivalent of SQL's query `like '%string%'`

# %%
for document in db.products.find({"category": re.compile("electron", re.IGNORECASE)}):
  print(document)

# %% [markdown]
# find all products with price less than 40 AND category Clothing

# %%
for document in db.products.find({'price': {'$lt':40},'category': 'Clothing'}):
  print(document)

# %% [markdown]
# ## Orders

# %%
# Calculate the total number of orders
pipeline = [
    {
        '$unwind': '$orders'
    },
    {
        '$group': {
            '_id': None,
            'total_orders': {'$sum': 1}
        }
    },
    {
        '$project': {
            '_id': 0,
            'total_orders': 1
        }
    }
]

result = db.customers.aggregate(pipeline)

# Extract the total number of orders
total_orders = next(result)['total_orders']

# Print the total number of orders
print(f"Total Orders: {total_orders}")

# %%
filter_criteria = {
    'orders.units': {'$lt': 45000}
}

# Calculate the total number of orders with units less than 12000
pipeline = [
    {
      '$unwind': '$orders'
    },
    {
      '$match': filter_criteria
    },
    {
        '$group': {
            '_id': None,
            'total_orders': {'$sum': 1}
        }
    },
    {
        '$project': {
            '_id': 0,
            'total_orders': 1
        }
    }
]

result = db.customers.aggregate(pipeline)

# Extract the total number of orders
total_orders = next(result)['total_orders']

# Print the total number of orders
print(f"Total Orders: {total_orders}")

# %% [markdown]
# # Extraction

# %% [markdown]
# ## Dump mongodb data to json file.

# %% [markdown]
# create a JSON file with the filtered data.

# %%
from bson.json_util import dumps
import json

# %% [markdown]
# open a file. create a cursor that gets passed to dumps which takes binary json data and converts it serialized json, deseralizes it to python object and then serializes it back to a file.

# %% [markdown]
# ## dump orders

# %% [markdown]
# ## dump customers
#
# (and orders as they are nested)

# %%
with open('customers.json', 'w') as file:
  cursor = db.customers.find({})
  file.write(dumps(cursor))

# %% [markdown]
# ## dump products

# %%
with open('products.json', 'w') as file:
  cursor = db.products.find({})
  file.write(dumps(cursor))

# %%
# !ls -lh *.json

# %% [markdown]
# # Reading JSON file data into Python

# %% [markdown]
# ## JSON into Pandas DataFrame

# %%
import pandas as pd

# %%
customers_df = pd.read_json('customers.json')
customers_df.head(2)

# %%
products_df = pd.read_json('products.json')
products_df.head(2)

# %% [markdown]
# ### Merge DataFrames

# %%
customers_df.head(4)

# %%
orders_df = customers_df.explode('orders')

# %%
df_orders_expanded = pd.concat([orders_df.drop(['orders'], axis=1), orders_df['orders'].apply(pd.Series)], axis=1)
df_orders_expanded.head(3)

# %%
customer_product_orders = df_orders_expanded.merge(products_df, on='productid', how='left')
customer_product_orders.head(3)

# %%
customer_product_orders['total_sales'] = customer_product_orders['price'] * customer_product_orders['units']

# %%
customer_product_orders.groupby(by='category').agg({'total_sales': 'sum'}).sort_values(by='total_sales', ascending=False)

# %% [markdown]
# How to unzip a zip file.

# %%
# !wget -O patient_records.zip https://github.com/matthewpecsok/data_engineering/raw/main/data/patient_records.zip

# %%
# !ls -l

# %%
# !unzip patient_records.zip

# %%
# !wget -O medication_database.db https://github.com/matthewpecsok/data_engineering/raw/main/data/medication_database.db

# %%
import sqlite3
import pandas as pd

# %%
medication_con = sqlite3.connect('medication_database.db')

pd.read_sql_query('SELECT * FROM sqlite_master', medication_con)

# %%
pd.read_sql_query('SELECT * FROM medications', medication_con)

# %%
import json

# %%
patients_1_batch = json.load(open('patient_records_batch_1.json'))

# %%
len(patients_1_batch)

# %%
patients_1_batch[0:20]
